# %%
# Define model
import keras.layers as L
import keras.losses as losses
import keras.models as M
import keras.optimizers as opt
from keras.utils import to_categorical
# Out:
# /Users/ateendraramesh/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
import spacy 
import re
from sklearn import cross_validation, metrics
import seaborn as sns
# %matplotlib inline
# Out:
# /Users/ateendraramesh/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
# Plot settings
plt.style.use('seaborn-dark-palette')
plt.interactive(True)
plt.rcParams['figure.figsize'] = (20, 10)

# %%
# GLoVE vector dictionary
vector = None

# %%
df = pd.read_csv('../../data/1900-01-01-2019-02-18-India.csv')

# %%
counter = Counter(df.location)
counter = sorted(counter.items(), key=lambda x: -x[1])[:15]
counter = np.array(counter)

print ([x[0] for x in counter])

places, counts = counter[:, 0].tolist(), counter[:, 1].astype(np.float32)
indices = np.arange(len(counts))
width = 1

plt.xlabel("Location")
plt.ylabel("Number of articles")
plt.interactive(True)

plt.xticks(indices + 0.125, places)
plt.title("Top 10 news generating locations")
_ = plt.bar(indices, counts, 0.5)
# Out:
# ['Jammu', 'Srinagar', 'Delhi-New Delhi', 'Bathinda', 'Dehradun', 'Chandigarh', 'Ludhiana', 'Amritsar', 'Lucknow', 'Imphal', 'Jalandhar', 'Kolkata', 'Guwahati', 'Chennai', 'Patiala']

# %%
df['event_date'] = pd.to_datetime(df['event_date'])
df.sort_values(by=['event_date'], inplace=True)

# %%
dates = pd.date_range(start=df.iloc[0]['event_date'], end=df.iloc[-1]['event_date'])
print("Number of days -", len(dates))
# Out:
# Number of days - 1136

# %%
dates[0], dates[-1]
# Out:
# (Timestamp('2016-01-01 00:00:00', freq='D'),
#  Timestamp('2019-02-09 00:00:00', freq='D'))

# %%
df = df[df['location'] == "Nagpur"]

num_events = np.zeros(len(dates))
i = 0
for date in dates:
    num_events[i] += len(df[df['event_date'] == date])
    i += 1

# %%
plt.title("Number of events over time")
plt.xlabel("Time")
plt.ylabel("Number of events")
_ = plt.bar(np.arange(len(num_events)), num_events)

# %%
news_articles = df.notes

# %%
def get_glove_dict():
    """
    Inputs - None
    
    Returns - Dict below
    
    Create a dict with word as key and word vector as value
    """
    d = {}
    f = open("../../glove_vectors/glove.6B.300d.txt", 'r')
    for row in f:
        row = row.replace('\n', '').split(" ")
        word = row[0]
        vector = np.array([float(x) for x in row[1:]])
        d[word] = vector
    f.close()
    return d

def generate_labels(num_events, num_days=2, days_window=2):
    """
    Inputs - 
        num_events - as generated as above 
        num_days - the number of days to after which we 
                   look for the occurence of an event.
                   Basically, the future
        day_window - If an event occurs in a window of days
                     after num_days
    
    Returns - Returns labels generated as below
    
    Generate labels by using the future events, basically
    look-ahead to create labels. If an event occurs from 
    i to i + num_days, then label is 1.0 else 0.0
    """
    n = len(num_events)
    labels = np.zeros(n - num_days - days_window)
    for i in range(n - num_days - days_window):
        labels[i] = 1.0 if sum(num_events[i + num_days: i + num_days + days_window] > 0) else 0.0
    return labels

# %%
if vector is None:
    vector = get_glove_dict()

# %%
num_days, days_window = 2, 5
labels = generate_labels(num_events, num_days, days_window)

# %%
print(labels.shape)
# Out:
# (1129,)

# %%
plt.title('Label Distribution')
plt.xlabel('Ground Truth')
plt.ylabel('hasEventOcurred')
_ = plt.hist(labels, bins=3, range=(0, 1))

# %%
# Tokenizer
nlp = spacy.load('en_core_web_sm')

# Generate sentence vectors
sentence_vectors = []
regexp = r'/[.,\/#!$%\^&\*;:{}=\-_`~()]/g'
num_sentences = len(news_articles)

for i, sentence in enumerate(news_articles):
    if i % 100 == 0:
        print (i, " / ", num_sentences, "done!")
    tokens = [t.text.lower() for t in nlp(sentence)]
    temp = []
    for token in tokens:
        vec = vector.get(token)
        if vec is None:
            vec = vector['unk']
        temp.append(vec)
    sentence_vectors.append(temp)
# Out:
# 0  /  1492 done!
# 100  /  1492 done!
# 200  /  1492 done!
# 300  /  1492 done!
# 400  /  1492 done!
# 500  /  1492 done!
# 600  /  1492 done!
# 700  /  1492 done!
# 800  /  1492 done!
# 900  /  1492 done!
# 1000  /  1492 done!
# 1100  /  1492 done!
# 1200  /  1492 done!
# 1300  /  1492 done!
# 1400  /  1492 done!

# %%
# For the sentence vector, currently, simply just use average of all words vectors
for i, vecs in enumerate(sentence_vectors):
    sentence_vectors[i] = np.mean(vecs, axis=0)

# %%
sentence_vectors = np.array(sentence_vectors)
print("Sentence vector shape -", sentence_vectors.shape)

vector_dim = sentence_vectors.shape[-1]
# Out:
# Sentence vector shape - (1492, 300)

# %%
df.index = np.arange(len(df))
df.head(5)
# Out:
#    data_id  iso event_id_cnty  event_id_no_cnty event_date  year  \
# 0  2033551  356         IND57              57.0 2016-01-03  2016
# 1  2035847  356         IND85              85.0 2016-01-04  2016
# 2  2035765  356         IND84              84.0 2016-01-04  2016
# 3  2010551  356        IND120             120.0 2016-01-05  2016
# 4  2016657  356        IND193             193.0 2016-01-08  2016
#
#    time_precision      event_type              actor1  \
# 0               1  Riots/Protests  Protesters (India)
# 1               1  Riots/Protests  Protesters (India)
# 2               1  Riots/Protests  Protesters (India)
# 3               1  Riots/Protests  Protesters (India)
# 4               1  Riots/Protests  Protesters (India)
#
#                                       assoc_actor_1 ...   location latitude  \
# 0  JKNPP: Jammu and Kashmir National Panthers Party ...      Jammu  32.7357
# 1           NSUI: National Students' Union of India ...      Jammu  32.7357
# 2                JWAM: Jammu West Assembly Movement ...      Jammu  32.7357
# 3             Former Police Forces of India (2014-) ...      Jammu  32.7357
# 4                              Labour Group (India) ...      Jammu  32.7357
#
#   longitude  geo_precision               source source_scale  \
# 0   74.8691              1  Early Times (India)  Subnational
# 1   74.8691              1           Northlines  Subnational
# 2   74.8691              1           Northlines  Subnational
# 3   74.8691              1           Northlines  Subnational
# 4   74.8691              1  Early Times (India)  Subnational
#
#                                                notes fatalities   timestamp  \
# 0  On Jan 03, activists of Jammu and Kashmir Nati...          0  1542756339
# 1  On Jan 04, the National Students Union of Indi...          0  1542756341
# 2  On Jan 04, an anti-Pakistan protest rally was ...          0  1542756341
# 3  On Jan 05, all J&K Retired Police Personnel Fo...          0  1542756306
# 4  On Jan 08, the Food & Allied workers Union Jam...          0  1542756322
#
#   iso3
# 0  IND
# 1  IND
# 2  IND
# 3  IND
# 4  IND
#
# [5 rows x 30 columns]

# %%
sentence_dict = {}
for date in dates:
    temp_df = df[df['event_date'] == date]
    
    if len(temp_df) == 0:
        sentence_dict[date] = (np.zeros(vector_dim))

    else:
        indices = list(temp_df.index)
        sentence_dict[date] = sentence_vectors[indices]

# %% [markdown]
# ### Using average of averages

# %%
vec_date = []
for date in dates:
    arr = sentence_dict[date].reshape(-1, vector_dim)
    vec_date.append(np.mean(arr, axis=0))

# %%
history = 5
n = len(dates)

# %%
x, y = [], []
for i in range(history, n - num_days - days_window):
    x.append(vec_date[i - history: i])
    y.append(labels[i])

# %%
x, y = np.array(x), np.array(y)
# p = np.random.permutation(len(x))
# x, y = x[p], y[p]

# %%
print(x.shape, y.shape)
# Out:
# (1124, 5, 300) (1124,)

# %%
split = int(len(x) * 0.8)
xtrain, xtest = x[:split], x[split:]
ytrain, ytest = y[:split], y[split:]
ytrain, ytest = to_categorical(ytrain), to_categorical(ytest)

# %%
model = M.Sequential()
model.add(L.LSTM(30, return_sequences=True, input_shape=(history, vector_dim)))# , kernel_size=3))
model.add(L.LeakyReLU())
model.add(L.Dropout(0.2))

model.add(L.LSTM(15, input_shape=(history, vector_dim)))# , kernel_size=3))
model.add(L.LeakyReLU())
model.add(L.Dropout(0.2))

# model.add(L.GlobalMaxPool1D())

model.add(L.Dense(10))

model.add(L.Dense(2, activation='softmax'))

opzr = opt.Adam(0.001)
model.compile(opzr, loss=losses.binary_crossentropy, metrics=['accuracy'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_23_input (InputLayer)   (None, 5, 300)            0
# _________________________________________________________________
# lstm_23 (LSTM)               (None, 5, 30)             39720
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 5, 30)             0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 5, 30)             0
# _________________________________________________________________
# lstm_24 (LSTM)               (None, 15)                2760
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 15)                0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 15)                0
# _________________________________________________________________
# dense_43 (Dense)             (None, 10)                160
# _________________________________________________________________
# dense_44 (Dense)             (None, 2)                 22
# =================================================================
# Total params: 42,662
# Trainable params: 42,662
# Non-trainable params: 0
# _________________________________________________________________

# %%
print('Train shape -', xtrain.shape)
print('Test shape -', xtest.shape)
# Out:
# Train shape - (899, 5, 300)
# Test shape - (225, 5, 300)

# %%
model.fit(xtrain, ytrain, validation_data=(xtest, ytest), batch_size=32, epochs=40)
# Out:
# Train on 899 samples, validate on 225 samples
# Epoch 1/40
# 899/899 [==============================] - 5s 6ms/step - loss: 0.3887 - acc: 0.9466 - val_loss: 0.0325 - val_acc: 1.0000
# Epoch 2/40
# 899/899 [==============================] - 0s 425us/step - loss: 0.1838 - acc: 0.9555 - val_loss: 0.0155 - val_acc: 1.0000
# Epoch 3/40
# 899/899 [==============================] - 0s 425us/step - loss: 0.1771 - acc: 0.9555 - val_loss: 0.0174 - val_acc: 1.0000
# Epoch 4/40
# 899/899 [==============================] - 0s 420us/step - loss: 0.1803 - acc: 0.9555 - val_loss: 0.0211 - val_acc: 1.0000
# Epoch 5/40
# 899/899 [==============================] - 0s 421us/step - loss: 0.1729 - acc: 0.9555 - val_loss: 0.0208 - val_acc: 1.0000
# Epoch 6/40
# 899/899 [==============================] - 0s 410us/step - loss: 0.1729 - acc: 0.9555 - val_loss: 0.0201 - val_acc: 1.0000
# Epoch 7/40
# 899/899 [==============================] - 0s 379us/step - loss: 0.1640 - acc: 0.9555 - val_loss: 0.0236 - val_acc: 1.0000
# Epoch 8/40
# 899/899 [==============================] - 0s 421us/step - loss: 0.1691 - acc: 0.9555 - val_loss: 0.0248 - val_acc: 1.0000
# Epoch 9/40
# 899/899 [==============================] - 0s 385us/step - loss: 0.1649 - acc: 0.9555 - val_loss: 0.0161 - val_acc: 1.0000
# Epoch 10/40
# 899/899 [==============================] - 0s 409us/step - loss: 0.1565 - acc: 0.9555 - val_loss: 0.0189 - val_acc: 1.0000
# Epoch 11/40
# 899/899 [==============================] - 0s 427us/step - loss: 0.1415 - acc: 0.9555 - val_loss: 0.0135 - val_acc: 1.0000
# Epoch 12/40
# 899/899 [==============================] - 0s 419us/step - loss: 0.1406 - acc: 0.9555 - val_loss: 0.0768 - val_acc: 1.0000
# Epoch 13/40
# 899/899 [==============================] - 0s 397us/step - loss: 0.1325 - acc: 0.9566 - val_loss: 0.0244 - val_acc: 1.0000
# Epoch 14/40
# 899/899 [==============================] - 0s 399us/step - loss: 0.1121 - acc: 0.9588 - val_loss: 0.2401 - val_acc: 0.8933
# Epoch 15/40
# 899/899 [==============================] - 0s 409us/step - loss: 0.1279 - acc: 0.9555 - val_loss: 0.0376 - val_acc: 0.9911
# Epoch 16/40
# 899/899 [==============================] - 0s 406us/step - loss: 0.1180 - acc: 0.9588 - val_loss: 0.0170 - val_acc: 0.9911
# Epoch 17/40
# 899/899 [==============================] - 0s 400us/step - loss: 0.1209 - acc: 0.9588 - val_loss: 0.0161 - val_acc: 1.0000
# Epoch 18/40
# 899/899 [==============================] - 0s 417us/step - loss: 0.1008 - acc: 0.9644 - val_loss: 0.0415 - val_acc: 0.9778
# Epoch 19/40
# 899/899 [==============================] - 0s 406us/step - loss: 0.1042 - acc: 0.9622 - val_loss: 0.0278 - val_acc: 0.9867
# Epoch 20/40
# 899/899 [==============================] - 0s 406us/step - loss: 0.1141 - acc: 0.9600 - val_loss: 0.0451 - val_acc: 0.9867
# Epoch 21/40
# 899/899 [==============================] - 0s 404us/step - loss: 0.0886 - acc: 0.9655 - val_loss: 0.1165 - val_acc: 0.9511
# Epoch 22/40
# 899/899 [==============================] - 0s 413us/step - loss: 0.0905 - acc: 0.9700 - val_loss: 0.0374 - val_acc: 0.9822
# Epoch 23/40
# 899/899 [==============================] - 0s 389us/step - loss: 0.0892 - acc: 0.9711 - val_loss: 0.1451 - val_acc: 0.9467
# Epoch 24/40
# 899/899 [==============================] - 0s 430us/step - loss: 0.0707 - acc: 0.9789 - val_loss: 0.1052 - val_acc: 0.9467
# Epoch 25/40
# 899/899 [==============================] - 0s 453us/step - loss: 0.0713 - acc: 0.9744 - val_loss: 0.4726 - val_acc: 0.7689
# Epoch 26/40
# 899/899 [==============================] - 0s 495us/step - loss: 0.0731 - acc: 0.9755 - val_loss: 0.0418 - val_acc: 0.9778
# Epoch 27/40
# 899/899 [==============================] - 1s 573us/step - loss: 0.0711 - acc: 0.9778 - val_loss: 0.1778 - val_acc: 0.9289
# Epoch 28/40
# 899/899 [==============================] - 1s 591us/step - loss: 0.0648 - acc: 0.9778 - val_loss: 0.5328 - val_acc: 0.7733
# Epoch 29/40
# 899/899 [==============================] - 0s 526us/step - loss: 0.0762 - acc: 0.9800 - val_loss: 0.1663 - val_acc: 0.9333
# Epoch 30/40
# 899/899 [==============================] - 0s 530us/step - loss: 0.0647 - acc: 0.9744 - val_loss: 0.1480 - val_acc: 0.9467
# Epoch 31/40
# 899/899 [==============================] - 0s 525us/step - loss: 0.0541 - acc: 0.9833 - val_loss: 0.2322 - val_acc: 0.9200
# Epoch 32/40
# 899/899 [==============================] - 0s 500us/step - loss: 0.0497 - acc: 0.9833 - val_loss: 0.1877 - val_acc: 0.9378
# Epoch 33/40
# 899/899 [==============================] - 0s 531us/step - loss: 0.0565 - acc: 0.9800 - val_loss: 0.1388 - val_acc: 0.9422
# Epoch 34/40
# 899/899 [==============================] - 0s 510us/step - loss: 0.0495 - acc: 0.9822 - val_loss: 0.2949 - val_acc: 0.8844
# Epoch 35/40
# 899/899 [==============================] - 0s 529us/step - loss: 0.0538 - acc: 0.9833 - val_loss: 0.2002 - val_acc: 0.9244
# Epoch 36/40
# 899/899 [==============================] - 0s 493us/step - loss: 0.0478 - acc: 0.9822 - val_loss: 0.2021 - val_acc: 0.9289
# Epoch 37/40
# 899/899 [==============================] - 0s 505us/step - loss: 0.0467 - acc: 0.9855 - val_loss: 0.1289 - val_acc: 0.9511
# Epoch 38/40
# 899/899 [==============================] - 0s 430us/step - loss: 0.0456 - acc: 0.9833 - val_loss: 0.2608 - val_acc: 0.8978
# Epoch 39/40
# 899/899 [==============================] - 0s 443us/step - loss: 0.0510 - acc: 0.9833 - val_loss: 0.1681 - val_acc: 0.9378
# Epoch 40/40
# 899/899 [==============================] - 0s 442us/step - loss: 0.0442 - acc: 0.9844 - val_loss: 0.0972 - val_acc: 0.9689

# %%
pred = model.predict(xtest)
if len(pred.shape) == 1:
    ytest_ = ytest
else:
    pred = model.predict_proba(xtest) [:, 1]
    threshold = 0.68
    pred[pred > threshold] = 1
    pred[pred <= threshold] = 0
    ytest_ = np.argmax(ytest, axis=1)

# %%
print(metrics.classification_report(ytest_, pred))
# Out:
#              precision    recall  f1-score   support
#
#         0.0       0.00      0.00      0.00         0
#         1.0       1.00      0.96      0.98       225
#
# avg / total       1.00      0.96      0.98       225
# /Users/ateendraramesh/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1137: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %%
conf_mat = metrics.confusion_matrix(ytest_, pred)
# conf_mat = conf_mat * 100. / np.sum(conf_mat, axis=1, keepdims=True)

# %%
conf_mat
# Out:
# array([[  0,   0],
#        [  9, 216]])

# %% [markdown]
# ### Using news articles as such

# %%
history = 5
n = len(dates)

# %%
x, y = [], []
for date in dates:
    sentence_vecs = sentence_dict[date]
